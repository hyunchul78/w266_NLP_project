# %%
from tensorflow.keras.layers import Bidirectional, Dense, Embedding, Input, Lambda, LSTM, RepeatVector, TimeDistributed, Layer, Activation, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import ELU
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from scipy import spatial
import tensorflow as tf
import pandas as pd
import numpy as np
import codecs
import csv
import os
# Out:
# /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13380848502337166963
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7213351567917891643
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4226399986390007445
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 9684543079
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6460742585755723852
# physical_device_desc: "device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %% [markdown]
# ### Directories and text loading
# Initially we will set the main directories and some variables regarding the characteristics of our texts.
# We set the maximum sequence length to 15, the maximun number of words in our vocabulary to 12000 and we will use 50-dimensional embeddings. Finally we load our texts from a csv. The text file is the train file of the Quora Kaggle challenge containing around 808000 sentences.

# %% [markdown]
# #### CSV (Comma Separated Values)
# Format for spreadsheets and databases
# - reader object: Return a reader object which will iterate over lines in the given csvfile.
# - writer object

# %%
BASE_DIR = '/home/ines/nlp_project/text_VAE/'
TRAIN_DATA_FILE = BASE_DIR + 'train.csv'#'train_micro.csv'
GLOVE_EMBEDDING = BASE_DIR + 'GloVe/glove.6B.50d.txt'
VALIDATION_SPLIT = 0.2
MAX_SEQUENCE_LENGTH = 15
MAX_NB_WORDS = 12000
EMBEDDING_DIM = 50

texts = [] 
with codecs.open(TRAIN_DATA_FILE, encoding='utf-8') as f:
    reader = csv.reader(f, delimiter=',')
    header = next(reader)
    for values in reader:
        texts.append(values[3])
        texts.append(values[4])
print('Found %s texts in train.csv' % len(texts))
# Out:
# Found 808580 texts in train.csv

# %% [markdown]
# ### Text Preprocessing
# To preprocess the text we will use the tokenizer and the text_to_sequences function from Keras
#
# - `Tokenizer(num_words)`

# %%
tokenizer = Tokenizer(MAX_NB_WORDS)
tokenizer.fit_on_texts(texts)

# {key=word : value:index}
word_index = tokenizer.word_index #the dict values start from 1 so this is fine with zeropadding
# {key=index : value:word}
index2word = {v: k for k, v in word_index.items()}
print('Found %s unique tokens' % len(word_index))

# Return index list of Char array 
sequences = tokenizer.texts_to_sequences(texts)
# Return (sample, MAX_SEQUENCE_LENGTH) size integer tensor
data_1 = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', data_1.shape)
NB_WORDS = (min(tokenizer.num_words, len(word_index)) + 1 ) #+1 for zero padding
data_1_val = data_1[801000:807000] #select 6000 sentences as validation data
# Out:
# Found 95596 unique tokens
# Shape of data tensor: (808580, 15)

# %%
print(texts[0])
print(sequences[0])

print(texts[1000])
print(sequences[1000])
# Out:
# What is the step by step guide to invest in share market in india?
# [2, 3, 1, 1222, 57, 1222, 2581, 7, 576, 8, 763, 383, 8, 35]
# What does it mean when a guy says I like you?
# [2, 21, 19, 101, 37, 6, 287, 716, 5, 39, 15]

# %% [markdown]
# ### Sentence generator
# In order to reduce the memory requirements we will gradually read our sentences from the csv through Pandas as we feed them to the model

# %%
def sent_generator(TRAIN_DATA_FILE, chunksize):
    reader = pd.read_csv(TRAIN_DATA_FILE, chunksize=chunksize, iterator=True)
    for df in reader:
        #print(df.shape)
        #df=pd.read_csv(TRAIN_DATA_FILE, iterator=False)
        val3 = df.iloc[:,3:4].values.tolist()
        val4 = df.iloc[:,4:5].values.tolist()
        flat3 = [item for sublist in val3 for item in sublist]
        flat4 = [str(item) for sublist in val4 for item in sublist]
        texts = [] 
        # 'Append' add x, but extend add x's elements
        texts.extend(flat3[:]) # Column Question1
        texts.extend(flat4[:]) # Column Question2
        sequences = tokenizer.texts_to_sequences(texts)
        data_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
        yield (data_train, data_train)

# %% [markdown]
# ### Word embeddings
# We will use pretrained Glove word embeddings as embeddings for our network. We create a matrix with one embedding for every word in our vocabulary and then we will pass this matrix as weights to the keras embedding layer of our model

# %% [markdown]
# the 0.418 0.24968 -0.41242 0.1217 0.34527 -0.044457 -0.49688 -0.17862 -0.00066023 -0.6566 0.27843 -0.14767 -0.55677 0.14658 -0.0095095 0.011658 0.10204 -0.12792 -0.8443 -0.12181 -0.016801 -0.33279 -0.1552 -0.23131 -0.19181 -1.8823 -0.76746 0.099051 -0.42125 -0.19526 4.0071 -0.18594 -0.52287 -0.31681 0.00059213 0.0074449 0.17778 -0.15897 0.012041 -0.054223 -0.29871 -0.15749 -0.34758 -0.045637 -0.44251 0.18785 0.0027849 -0.18411 -0.11514 -0.78581

# %%
embeddings_index = {}
f = open(GLOVE_EMBEDDING, encoding='utf8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))

glove_embedding_matrix = np.zeros((NB_WORDS, EMBEDDING_DIM))
for word, i in word_index.items():
    if i < NB_WORDS:
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            # words not found in embedding index will be the word embedding of 'unk'.
            glove_embedding_matrix[i] = embedding_vector
        else:
            glove_embedding_matrix[i] = embeddings_index.get('unk')
print('Null word embeddings: %d' % np.sum(np.sum(glove_embedding_matrix, axis=1) == 0))
# Out:
# Found 400000 word vectors.
# Null word embeddings: 1

# %% [markdown]
# ### VAE model
# Our model is based on a seq2seq architecture with a bidirectional LSTM encoder and an LSTM decoder and ELU activations.
# We feed the latent representation at every timestep as input to the decoder through "RepeatVector(max_len)".
# To avoid the one-hot representation of labels we use the "tf.contrib.seq2seq.sequence_loss" that requires as labels only the word indexes (the same that go in input to the embedding matrix) and calculates internally the final softmax (so the model ends with a dense layer with linear activation). Optionally the "sequence_loss" allows to use the sampled softmax which helps when dealing with large vocabularies (for example with a 50k words vocabulary) but in this I didn't use it.
# Moreover, due to the pandas iterator that reads the csv both the train size and validation size must be divisible by the batch_size.

# %% [markdown]
# Exponential Linear Unit or its widely known name ELU is a function that tend to converge cost to zero faster and produce more accurate results. Different to other activation functions, ELU has a extra alpha constant which should be positive number.
#
# ELU is very similiar to RELU except negative inputs. They are both in identity function form for non-negative inputs. On the other hand, ELU becomes smooth slowly until its output equal to -α whereas RELU sharply smoothes.
#
# https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html#elu

# %%
batch_size = 100
max_len = MAX_SEQUENCE_LENGTH
emb_dim = EMBEDDING_DIM
latent_dim = 32
intermediate_dim = 96
epsilon_std = 1.0
num_sampled=500
act = ELU()
repeated_context = RepeatVector(max_len)

#y = Input(batch_shape=(None, max_len, NB_WORDS))
x = Input(batch_shape=(None, max_len))
x_embed = Embedding(NB_WORDS, emb_dim, weights=[glove_embedding_matrix],
                            input_length=max_len, trainable=False)(x)
h = Bidirectional(LSTM(intermediate_dim*2,return_sequences=True))(x_embed)
h = Bidirectional(LSTM(intermediate_dim, return_sequences=False, recurrent_dropout=0.2), merge_mode='concat')(h)

h = Dropout(0.2)(h)
h = Dense(intermediate_dim, activation='linear')(h)
h = act(h)
h = Dropout(0.2)(h)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0.,
                              stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2) * epsilon

# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# we instantiate these layers separately so as to reuse them later
repeated_context = RepeatVector(max_len)
decoder_h1 = LSTM(intermediate_dim, return_sequences=True, recurrent_dropout=0.2)
decoder_h2 = LSTM(intermediate_dim*2, return_sequences=True, recurrent_dropout=0.2)
decoder_mean = TimeDistributed(Dense(NB_WORDS, activation='linear'))#softmax is applied in the seq2seqloss by tf

h_decoded1 = decoder_h1(repeated_context(z))
h_decoded2 = decoder_h2(h_decoded1)
x_decoded_mean = decoder_mean(h_decoded2)


# placeholder loss
def zero_loss(y_true, y_pred):
    return K.zeros_like(y_pred)

#=========================== Necessary only if you want to use Sampled Softmax =======================#
#Sampled softmax
logits = tf.constant(np.random.randn(batch_size, max_len, NB_WORDS), tf.float32)
targets = tf.constant(np.random.randint(NB_WORDS, size=(batch_size, max_len)), tf.int32)
proj_w = tf.constant(np.random.randn(NB_WORDS, NB_WORDS), tf.float32)
proj_b = tf.constant(np.zeros(NB_WORDS), tf.float32)

def _sampled_loss(labels, logits):
    labels = tf.cast(labels, tf.int64)
    labels = tf.reshape(labels, [-1, 1])
    logits = tf.cast(logits, tf.float32)
    return tf.cast(
                    tf.nn.sampled_softmax_loss(
                        proj_w,
                        proj_b,
                        labels,
                        logits,
                        num_sampled=num_sampled,
                        num_classes=NB_WORDS),
                    tf.float32)
softmax_loss_f = _sampled_loss
#====================================================================================================#

# Custom VAE loss layer
class CustomVariationalLayer(Layer):
    def __init__(self, **kwargs):
        self.is_placeholder = True
        super(CustomVariationalLayer, self).__init__(**kwargs)
        self.target_weights = tf.constant(np.ones((batch_size, max_len)), tf.float32)

    def vae_loss(self, x, x_decoded_mean):
        #xent_loss = K.sum(metrics.categorical_crossentropy(x, x_decoded_mean), axis=-1)
        labels = tf.cast(x, tf.int32)
        xent_loss = K.sum(tf.contrib.seq2seq.sequence_loss(x_decoded_mean, labels, 
                                                     weights=self.target_weights,
                                                     average_across_timesteps=False,
                                                     average_across_batch=False), axis=-1)
                                                     #softmax_loss_function=softmax_loss_f), axis=-1)#, uncomment for sampled doftmax
        kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return K.mean(xent_loss + kl_loss)

    def call(self, inputs):
        x = inputs[0]
        x_decoded_mean = inputs[1]
        print(x.shape, x_decoded_mean.shape)
        loss = self.vae_loss(x, x_decoded_mean)
        self.add_loss(loss, inputs=inputs)
        # we don't use this output, but it has to have the correct shape:
        return K.ones_like(x)

loss_layer = CustomVariationalLayer()([x, x_decoded_mean])
vae = Model(x, [loss_layer])
opt = Adam(lr=0.01) #SGD(lr=1e-2, decay=1e-6, momentum=0.9, nesterov=True)
vae.compile(optimizer='adam', loss=[zero_loss])
vae.summary()
# Out:
# WARNING:tensorflow:From /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/keras/backend.py:4010: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# (?, 15) (100, 15, 12001)
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 15)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 15, 50)       600050      input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 15, 384)      373248      embedding[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 192)          369408      bidirectional[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 192)          0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 96)           18528       dropout[0][0]
# __________________________________________________________________________________________________
# elu (ELU)                       (None, 96)           0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 96)           0           elu[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           3104        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           3104        dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (100, 32)            0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (100, 15, 32)        0           lambda[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (100, 15, 96)        49536       repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (100, 15, 192)       221952      lstm_2[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (100, 15, 12001)     2316193     lstm_3[0][0]
# __________________________________________________________________________________________________
# custom_variational_layer (Custo (None, 15)           0           input_1[0][0]
#                                                                  time_distributed[0][0]
# ==================================================================================================
# Total params: 3,955,123
# Trainable params: 3,355,073
# Non-trainable params: 600,050
# __________________________________________________________________________________________________

# %% [markdown]
# ### Model training
# We train our model for 100 epochs through keras ".fit_generator". The number of steps per epoch is equal to the number of sentences that we have in the train set (800000) divided by the batch size; the additional /2 is due to the fact that our csv has two sentnces per line so in the end we have to read with our generator only 400000 lines per epoch.
# For validation data we pass the same array twice since input and labels of this model are the same.
# If we didn't use the "tf.contrib.seq2seq.sequence_loss" (or another similar function) we would have had to pass as labels the sequence of word one-hot encodings with dimension (batch_size, seq_len, vocab_size) consuming a lot of memory.

# %%
import datetime
from tensorflow.python.keras.callbacks import TensorBoard

# %%
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
callback = TensorBoard(log_dir)
callback.set_model([vae])

# %%
def write_log(callback, names, logs, batch_no):

    summary = tf.Summary()
    summary_value = summary.value.add()
    summary_value.simple_value = logs[0].history['loss'][0]
    summary_value.tag = names[0]
    callback.writer.add_summary(summary, batch_no)

    summary = tf.Summary()
    summary_value = summary.value.add()
    summary_value.simple_value = logs[0].history['val_loss'][0]
    summary_value.tag = names[1]
    callback.writer.add_summary(summary, batch_no)
    callback.writer.flush()

# %%
def create_model_checkpoint(dir, model_name):
    filepath = dir + '/' + model_name + ".h5" #-{epoch:02d}-{decoded_mean:.2f}
    directory = os.path.dirname(filepath)
    try:
        os.stat(directory)
    except:
        os.mkdir(directory)
    checkpointer = ModelCheckpoint(filepath=filepath, verbose=1, save_best_only=False)
    return checkpointer

checkpointer = create_model_checkpoint('models', 'vae_seq2seq')
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

nb_epoch=100
n_steps = int((800000/2)/batch_size)
for counter in range(nb_epoch):
    print('-------epoch: ',counter,'--------')
    history = vae.fit_generator(sent_generator(TRAIN_DATA_FILE, batch_size/2),
                          steps_per_epoch=n_steps, epochs=1, callbacks=[checkpointer],
                          validation_data=(data_1_val, data_1_val))
    write_log(callback, ['loss', 'val_loss'], [history], counter)
    
vae.save('models/50_e2_d2_ls32_itm96.h5')
# Out:
# -------epoch:  0 --------
# WARNING:tensorflow:From /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 6000/6000 [==============================] - 2s 365us/sample - loss: 64.4462
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 303s 76ms/step - loss: 69.1497 - val_loss: 64.4462
# -------epoch:  1 --------
# 6000/6000 [==============================] - 2s 301us/sample - loss: 63.2177
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 300s 75ms/step - loss: 64.0706 - val_loss: 63.2177
# -------epoch:  2 --------
# 6000/6000 [==============================] - 2s 306us/sample - loss: 62.6711
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 300s 75ms/step - loss: 63.2497 - val_loss: 62.6711
# -------epoch:  3 --------
# 6000/6000 [==============================] - 2s 304us/sample - loss: 62.3042
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 302s 76ms/step - loss: 62.7543 - val_loss: 62.3042
# -------epoch:  4 --------
# 6000/6000 [==============================] - 2s 305us/sample - loss: 62.1338
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 302s 76ms/step - loss: 62.4427 - val_loss: 62.1338
# -------epoch:  5 --------
# 6000/6000 [==============================] - 2s 306us/sample - loss: 62.0125
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 302s 76ms/step - loss: 62.2238 - val_loss: 62.0125
# -------epoch:  6 --------
# 6000/6000 [==============================] - 2s 287us/sample - loss: 61.9031
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 293s 73ms/step - loss: 62.0495 - val_loss: 61.9031
# -------epoch:  7 --------
# 6000/6000 [==============================] - 2s 289us/sample - loss: 61.7692
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 61.9056 - val_loss: 61.7692
# -------epoch:  8 --------
# 6000/6000 [==============================] - 2s 288us/sample - loss: 61.8603
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 61.7712 - val_loss: 61.8603
# -------epoch:  9 --------
# 6000/6000 [==============================] - 2s 291us/sample - loss: 61.6715
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 61.6395 - val_loss: 61.6715
# -------epoch:  10 --------
# 6000/6000 [==============================] - 2s 286us/sample - loss: 61.5966
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 61.4915 - val_loss: 61.5966
# -------epoch:  11 --------
# 6000/6000 [==============================] - 2s 288us/sample - loss: 61.2824
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 61.3093 - val_loss: 61.2824
# -------epoch:  12 --------
# 6000/6000 [==============================] - 2s 289us/sample - loss: 61.1859
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 61.1480 - val_loss: 61.1859
# -------epoch:  13 --------
# 6000/6000 [==============================] - 2s 291us/sample - loss: 61.1372
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 61.0153 - val_loss: 61.1372
# -------epoch:  14 --------
# 6000/6000 [==============================] - 2s 291us/sample - loss: 61.0560
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 60.8751 - val_loss: 61.0560
# -------epoch:  15 --------
# 6000/6000 [==============================] - 2s 289us/sample - loss: 60.9728
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 60.7996 - val_loss: 60.9728
# -------epoch:  16 --------
# 6000/6000 [==============================] - 2s 288us/sample - loss: 61.0035
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 60.6387 - val_loss: 61.0035
# -------epoch:  17 --------
# 6000/6000 [==============================] - 2s 288us/sample - loss: 60.7977
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 60.4804 - val_loss: 60.7977
# -------epoch:  18 --------
# 6000/6000 [==============================] - 2s 290us/sample - loss: 60.5320
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 60.3440 - val_loss: 60.5320
# -------epoch:  19 --------
# 6000/6000 [==============================] - 2s 287us/sample - loss: 60.4455
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 60.2237 - val_loss: 60.4455
# -------epoch:  20 --------
# 6000/6000 [==============================] - 2s 290us/sample - loss: 60.3390
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 60.0953 - val_loss: 60.3390
# -------epoch:  21 --------
# 6000/6000 [==============================] - 2s 289us/sample - loss: 60.2518
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 59.9858 - val_loss: 60.2518
# -------epoch:  22 --------
# 6000/6000 [==============================] - 2s 292us/sample - loss: 60.1606
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 288s 72ms/step - loss: 59.8906 - val_loss: 60.1606
# -------epoch:  23 --------
# 6000/6000 [==============================] - 2s 290us/sample - loss: 60.0838
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 59.8046 - val_loss: 60.0838
# -------epoch:  24 --------
# 6000/6000 [==============================] - 2s 288us/sample - loss: 59.9906
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 288s 72ms/step - loss: 59.7330 - val_loss: 59.9906
# -------epoch:  25 --------
# 6000/6000 [==============================] - 2s 290us/sample - loss: 60.0285
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 59.6529 - val_loss: 60.0285
# -------epoch:  26 --------
# 6000/6000 [==============================] - 2s 288us/sample - loss: 59.9158
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 288s 72ms/step - loss: 59.5975 - val_loss: 59.9158
# -------epoch:  27 --------
# 6000/6000 [==============================] - 2s 290us/sample - loss: 60.0284
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 288s 72ms/step - loss: 59.5430 - val_loss: 60.0284
# -------epoch:  28 --------
# 6000/6000 [==============================] - 2s 290us/sample - loss: 60.1746
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 287s 72ms/step - loss: 59.4886 - val_loss: 60.1746
# -------epoch:  29 --------
# 6000/6000 [==============================] - 2s 289us/sample - loss: 59.8957
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 288s 72ms/step - loss: 59.4412 - val_loss: 59.8957
# -------epoch:  30 --------
# 6000/6000 [==============================] - 2s 291us/sample - loss: 59.9259
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 288s 72ms/step - loss: 59.3923 - val_loss: 59.9259
# -------epoch:  31 --------
# 6000/6000 [==============================] - 2s 288us/sample - loss: 59.8574
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 288s 72ms/step - loss: 59.3437 - val_loss: 59.8574
# -------epoch:  32 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.9888
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 59.3173 - val_loss: 59.9888
# -------epoch:  33 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.9139
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 59.2581 - val_loss: 59.9139
# -------epoch:  34 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.8896
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 59.2260 - val_loss: 59.8896
# -------epoch:  35 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.9540
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 59.1967 - val_loss: 59.9540
# -------epoch:  36 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.8383
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 59.1675 - val_loss: 59.8383
# -------epoch:  37 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.8310
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 59.1258 - val_loss: 59.8310
# -------epoch:  38 --------
# 6000/6000 [==============================] - 2s 281us/sample - loss: 60.0296
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 59.1035 - val_loss: 60.0296
# -------epoch:  39 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.8709
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 59.0652 - val_loss: 59.8709
# -------epoch:  40 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 60.0877
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 59.0512 - val_loss: 60.0877
# -------epoch:  41 --------
# 6000/6000 [==============================] - 2s 281us/sample - loss: 59.9407
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 59.0269 - val_loss: 59.9407
# -------epoch:  42 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 60.0679
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.9867 - val_loss: 60.0679
# -------epoch:  43 --------
# 6000/6000 [==============================] - 2s 278us/sample - loss: 59.7947
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.9625 - val_loss: 59.7947
# -------epoch:  44 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 60.0849
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.9364 - val_loss: 60.0849
# -------epoch:  45 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.7560
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.9059 - val_loss: 59.7560
# -------epoch:  46 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.8469
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.8837 - val_loss: 59.8469
# -------epoch:  47 --------
# 6000/6000 [==============================] - 2s 282us/sample - loss: 59.7616
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.8556 - val_loss: 59.7616
# -------epoch:  48 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.8807
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.8459 - val_loss: 59.8807
# -------epoch:  49 --------
# 6000/6000 [==============================] - 2s 281us/sample - loss: 59.8531
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.8120 - val_loss: 59.8531
# -------epoch:  50 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.7067
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.7956 - val_loss: 59.7067
# -------epoch:  51 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.9621
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.7722 - val_loss: 59.9621
# -------epoch:  52 --------
# 6000/6000 [==============================] - 2s 282us/sample - loss: 59.8180
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.7471 - val_loss: 59.8180
# -------epoch:  53 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.7956
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.7265 - val_loss: 59.7956
# -------epoch:  54 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.7993
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.7214 - val_loss: 59.7993
# -------epoch:  55 --------
# 6000/6000 [==============================] - 2s 282us/sample - loss: 59.7669
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.6876 - val_loss: 59.7669
# -------epoch:  56 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.7197
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.6714 - val_loss: 59.7197
# -------epoch:  57 --------
# 6000/6000 [==============================] - 2s 283us/sample - loss: 59.6997
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.6484 - val_loss: 59.6997
# -------epoch:  58 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.7027
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.6421 - val_loss: 59.7027
# -------epoch:  59 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.6600
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.6083 - val_loss: 59.6600
# -------epoch:  60 --------
# 6000/6000 [==============================] - 2s 278us/sample - loss: 59.6834
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.5819 - val_loss: 59.6834
# -------epoch:  61 --------
# 6000/6000 [==============================] - 2s 282us/sample - loss: 59.7832
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.5828 - val_loss: 59.7832
# -------epoch:  62 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.8722
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.5540 - val_loss: 59.8722
# -------epoch:  63 --------
# 6000/6000 [==============================] - 2s 281us/sample - loss: 59.6223
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.5287 - val_loss: 59.6223
# -------epoch:  64 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.5786
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.5321 - val_loss: 59.5786
# -------epoch:  65 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.7055
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.5060 - val_loss: 59.7055
# -------epoch:  66 --------
# 6000/6000 [==============================] - 2s 281us/sample - loss: 59.5150
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.5005 - val_loss: 59.5150
# -------epoch:  67 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.6696
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.4912 - val_loss: 59.6696
# -------epoch:  68 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.6117
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.4799 - val_loss: 59.6117
# -------epoch:  69 --------
# 6000/6000 [==============================] - 2s 282us/sample - loss: 59.6554
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.4593 - val_loss: 59.6554
# -------epoch:  70 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.7389
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.4600 - val_loss: 59.7389
# -------epoch:  71 --------
# 6000/6000 [==============================] - 2s 278us/sample - loss: 59.5640
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.4484 - val_loss: 59.5640
# -------epoch:  72 --------
# 6000/6000 [==============================] - 2s 283us/sample - loss: 59.6261
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.4387 - val_loss: 59.6261
# -------epoch:  73 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.5616
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.5312 - val_loss: 59.5616
# -------epoch:  74 --------
# 6000/6000 [==============================] - 2s 281us/sample - loss: 59.5371
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 59.7431 - val_loss: 59.5371
# -------epoch:  75 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.6581
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.3754 - val_loss: 59.6581
# -------epoch:  76 --------
# 6000/6000 [==============================] - 2s 278us/sample - loss: 59.5763
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.3797 - val_loss: 59.5763
# -------epoch:  77 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.6826
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.3598 - val_loss: 59.6826
# -------epoch:  78 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.7129
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.3604 - val_loss: 59.7129
# -------epoch:  79 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.5560
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.3681 - val_loss: 59.5560
# -------epoch:  80 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.5862
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.3834 - val_loss: 59.5862
# -------epoch:  81 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.6742
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.3482 - val_loss: 59.6742
# -------epoch:  82 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.7098
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.3490 - val_loss: 59.7098
# -------epoch:  83 --------
# 6000/6000 [==============================] - 2s 281us/sample - loss: 59.6824
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.3618 - val_loss: 59.6824
# -------epoch:  84 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.6554
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.3320 - val_loss: 59.6554
# -------epoch:  85 --------
# 6000/6000 [==============================] - 2s 282us/sample - loss: 59.6299
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.3173 - val_loss: 59.6299
# -------epoch:  86 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.6610
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.2902 - val_loss: 59.6610
# -------epoch:  87 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.6936
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.2858 - val_loss: 59.6936
# -------epoch:  88 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.7293
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.2845 - val_loss: 59.7293
# -------epoch:  89 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.7827
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.2856 - val_loss: 59.7827
# -------epoch:  90 --------
# 6000/6000 [==============================] - 2s 283us/sample - loss: 59.6870
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 280s 70ms/step - loss: 58.2591 - val_loss: 59.6870
# -------epoch:  91 --------
# 6000/6000 [==============================] - 2s 281us/sample - loss: 60.1280
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.2457 - val_loss: 60.1280
# -------epoch:  92 --------
# 6000/6000 [==============================] - 2s 280us/sample - loss: 59.7390
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.2540 - val_loss: 59.7390
# -------epoch:  93 --------
# 6000/6000 [==============================] - 2s 282us/sample - loss: 59.6871
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.2587 - val_loss: 59.6871
# -------epoch:  94 --------
# 6000/6000 [==============================] - 2s 282us/sample - loss: 59.6479
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.2482 - val_loss: 59.6479
# -------epoch:  95 --------
# 6000/6000 [==============================] - 2s 281us/sample - loss: 59.7351
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 60.9437 - val_loss: 59.7351
# -------epoch:  96 --------
# 6000/6000 [==============================] - 2s 283us/sample - loss: 59.6759
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.2044 - val_loss: 59.6759
# -------epoch:  97 --------
# 6000/6000 [==============================] - 2s 278us/sample - loss: 59.6379
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.1789 - val_loss: 59.6379
# -------epoch:  98 --------
# 6000/6000 [==============================] - 2s 278us/sample - loss: 59.6905
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.3117 - val_loss: 59.6905
# -------epoch:  99 --------
# 6000/6000 [==============================] - 2s 279us/sample - loss: 59.6566
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 281s 70ms/step - loss: 58.2036 - val_loss: 59.6566

# %% [markdown]
# ### Model Load

# %%
vae.load_weights('models/50_e2_d2_ls32_itm96.h5')

# %% [markdown]
# ### Project and sample sentences from the latent space
# Now we build an encoder model that takes a sentence and projects it on the latent space
# and a decoder model that goes from the latent space back to the text representation

# %%
# build a model to project sentences on the latent space
encoder = Model(x, z_mean)
#encoder = Model(x, z_mean)

# build a generator that can sample sentences from the learned distribution
decoder_input = Input(shape=(latent_dim,))
_h_decoded1 = decoder_h1(repeated_context(decoder_input))
_h_decoded2 = decoder_h2(_h_decoded1)
_x_decoded_mean = decoder_mean(_h_decoded2)
_x_decoded_mean = Activation('softmax')(_x_decoded_mean)
generator = Model(decoder_input, _x_decoded_mean)

# %% [markdown]
# ### Test on validation sentences

# %%
index2word = {v: k for k, v in word_index.items()}
sent_encoded = encoder.predict(data_1_val, batch_size = 16)
x_test_reconstructed = generator.predict(sent_encoded)
max_value = np.apply_along_axis(np.argmax, 1, x_test_reconstructed[0])

# %%
sent_idx = 672
# Apply a function to 1-D slices along the given axis.
reconstructed_indexes = np.apply_along_axis(np.argmax, 1, x_test_reconstructed[sent_idx])
print(reconstructed_indexes)

#np.apply_along_axis(np.max, 1, x_test_reconstructed[sent_idx])
#np.max(np.apply_along_axis(np.max, 1, x_test_reconstructed[sent_idx]))
word_list = list(np.vectorize(index2word.get)(reconstructed_indexes))
word_list
# Out:
# [ 0  0 13  5 30  6  7  7  6  6  1  6  6  8 19]
# [None,
#  None,
#  'can',
#  'i',
#  'get',
#  'a',
#  'to',
#  'to',
#  'a',
#  'a',
#  'the',
#  'a',
#  'a',
#  'in',
#  'it']

# %%
original_sent = list(np.vectorize(index2word.get)(data_1_val[sent_idx]))
original_sent
# Out:
# [None,
#  'where',
#  'can',
#  'i',
#  'find',
#  'the',
#  'full',
#  'list',
#  'of',
#  'skills',
#  'for',
#  'the',
#  'linkedin',
#  'skills',
#  'feature']

# %% [markdown]
# ### Sentence processing and interpolation

# %%
# function to parse a sentence
def sent_parse(sentence, mat_shape):
    sequence = tokenizer.texts_to_sequences(sentence)
    padded_sent = pad_sequences(sequence, maxlen=MAX_SEQUENCE_LENGTH)
    return padded_sent#[padded_sent, sent_one_hot]

# input: encoded sentence vector
# output: encoded sentence vector in dataset with highest cosine similarity
def find_similar_encoding(sent_vect):
    all_cosine = []
    for sent in sent_encoded:
        result = 1 - spatial.distance.cosine(sent_vect, sent)
        all_cosine.append(result)
    data_array = np.array(all_cosine)
    maximum = data_array.argsort()[-3:][::-1][1]
    new_vec = sent_encoded[maximum]
    return new_vec

# input: two points, integer n
# output: n equidistant points on the line between the input points (inclusive)
def shortest_homology(point_one, point_two, num):
    dist_vec = point_two - point_one
    sample = np.linspace(0, 1, num, endpoint = True)
    hom_sample = []
    for s in sample:
        hom_sample.append(point_one + s * dist_vec)
    return hom_sample

# input: original dimension sentence vector
# output: sentence text
def print_latent_sentence(sent_vect):
    sent_vect = np.reshape(sent_vect,[1,latent_dim])
    sent_reconstructed = generator.predict(sent_vect)
    sent_reconstructed = np.reshape(sent_reconstructed,[max_len,NB_WORDS])
    reconstructed_indexes = np.apply_along_axis(np.argmax, 1, sent_reconstructed)
    np.apply_along_axis(np.max, 1, x_test_reconstructed[sent_idx])
    np.max(np.apply_along_axis(np.max, 1, x_test_reconstructed[sent_idx]))
    word_list = list(np.vectorize(index2word.get)(reconstructed_indexes))
    w_list = [w for w in word_list if w]
    print(' '.join(w_list))
    #print(word_list)
        
def new_sents_interp(sent1, sent2, n):
    tok_sent1 = sent_parse(sent1, [15])
    tok_sent2 = sent_parse(sent2, [15])
    enc_sent1 = encoder.predict(tok_sent1, batch_size = 16)
    enc_sent2 = encoder.predict(tok_sent2, batch_size = 16)
    test_hom = shortest_homology(enc_sent1, enc_sent2, n)
    for point in test_hom:
        print_latent_sentence(point)

# %%
example_sentence = ['where can i find the full list of skills for the linkedin skills feature']
mysent_sample = sent_parse(example_sentence, [15])
mysent_sample_encoded = encoder.predict(mysent_sample, batch_size=16)
print_latent_sentence(mysent_sample_encoded)
print_latent_sentence(find_similar_encoding(mysent_sample_encoded))
# Out:
# can i get a to to a a the a a in it
# is i get a to to a a the a a in it

# %% [markdown]
# ### Example
# Now we can try to parse two sentences and interpolate between them generating new sentences

# %%
sentence1=['where can i find a book on machine learning']
mysent = sent_parse(sentence1, [15])
mysent_encoded = encoder.predict(mysent, batch_size = 16)
print(mysent.shape, mysent_encoded.shape)
print_latent_sentence(mysent_encoded)
print_latent_sentence(find_similar_encoding(mysent_encoded))

sentence2=['how can i become a successful entrepreneur']
mysent2 = sent_parse(sentence2, [15])
mysent_encoded2 = encoder.predict(mysent2, batch_size = 16)
print_latent_sentence(mysent_encoded2)
print_latent_sentence(find_similar_encoding(mysent_encoded2))
print('-----------------')

new_sents_interp(sentence1, sentence2, 6)
# Out:
# (1, 15) (1, 32)
# how can i get my my in my quora
# how can i get my my in my quora
# how can i get my in quora
# how can i get my in quora
# -----------------
# how can i get my my in my quora
# what is the like to in in india
# how do i get my in in quora
# what is the best of in and
# do i like in in india
# how can i get my in quora

# %% [markdown]
# ### Results
# After training with these parameters for 100 epochs I got these results from interpolating between these two sentences:
#
# sentence1=['where can i find a book on machine learning']
# sentence2=['how can i become a successful entrepreneur']
#
# Generated sentences:
# - ------------------------------------------- -
# -  where can i find a book on machine learning
# -  where can i find a a machine book
# -  how can i write a a machine book
# -  how can i become a successful architect
# -  how can i become a successful architect
# -  how can i become a successful entrepreneur
# - ------------------------------------------- -
#
# As we can see the results are not yet completely satisfying because not all the sentences are grammatically correct and in the interpolation the same sentence has been generated multiple times but anyway the model, even in this preliminary version seems to start working.
# There are certainly many improvements that could be done like:
# -  removing all the sentences longer than 15 instead of just truncating them
# -  introduce the equivalent of word dropout used in the original paper for this decoder architecture
# -  parameter tuning (this model trains in few hours on a GTX950M with 2GB memory so it's definitely possible to try larger nets)
# -  Using word embeddings with higher dimensionality
# -  train on a more general dataset (Quora sentences are all questions)
#
# Stay tuned for future refinings of the model!
