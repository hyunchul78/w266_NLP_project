# %%
from tensorflow.keras.layers import Bidirectional, Dense, Embedding, Input, Lambda, LSTM, RepeatVector, TimeDistributed, Layer, Activation, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import ELU
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from scipy import spatial
import tensorflow as tf
import pandas as pd
import numpy as np
import codecs
import csv
import os

# %%
print(tf.__version__)
# Out:
# 1.13.2

# %%
#from tensorflow.python.client import device_lib
#print(device_lib.list_local_devices())

# %% [markdown]
# ### Directories and text loading
# Initially we will set the main directories and some variables regarding the characteristics of our texts.
# We set the maximum sequence length to 15, the maximun number of words in our vocabulary to 12000 and we will use 50-dimensional embeddings. Finally we load our texts from a csv. The text file is the train file of the Quora Kaggle challenge containing around 808000 sentences.

# %% [markdown]
# #### CSV (Comma Separated Values)
# Format for spreadsheets and databases

# %%
BASE_DIR = '[PATH to your Directory]'
TRAIN_DATA_FILE = BASE_DIR + 'train.csv'

texts = [] 
with codecs.open(TRAIN_DATA_FILE, encoding='utf-8') as f:
    reader = csv.reader(f, delimiter=',')
    header = next(reader)
    for values in reader:
        texts.append(values[3])
        texts.append(values[4])
print('Found %s texts in train.csv' % len(texts))
# Out:
# Found 808580 texts in train.csv

# %% [markdown]
# ### Text Preprocessing
# To preprocess the text we will use the tokenizer and the text_to_sequences function from Keras
#
# - `Tokenizer(num_words)`

# %%
MAX_SEQUENCE_LENGTH = 15
MAX_NB_WORDS = 12000

tokenizer = Tokenizer(MAX_NB_WORDS)
tokenizer.fit_on_texts(texts)

# {key=word : value:index}
word_index = tokenizer.word_index #the dict values start from 1 so this is fine with zeropadding
# {key=index : value:word}
index2word = {v: k for k, v in word_index.items()}
print('Found %s unique tokens' % len(word_index))

sequences = tokenizer.texts_to_sequences(texts)
data_1 = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', data_1.shape)

NB_WORDS = (min(tokenizer.num_words, len(word_index)) + 1 ) #+1 for zero padding
data_1_val = data_1[801000:807000] #select 6000 sentences as validation data
# Out:
# Found 95596 unique tokens
# Shape of data tensor: (808580, 15)

# %%
print(texts[0])
print(sequences[0])

print(texts[1000])
print(sequences[1000])
# Out:
# What is the step by step guide to invest in share market in india?
# [2, 3, 1, 1222, 57, 1222, 2581, 7, 576, 8, 763, 383, 8, 35]
# What does it mean when a guy says I like you?
# [2, 21, 19, 101, 37, 6, 287, 716, 5, 39, 15]

# %% [markdown]
# ### Sentence generator
# In order to reduce the memory requirements we will gradually read our sentences from the csv through Pandas as we feed them to the model

# %%
def sent_generator(TRAIN_DATA_FILE, chunksize):
    reader = pd.read_csv(TRAIN_DATA_FILE, chunksize=chunksize, iterator=True)
    for df in reader:
        val3 = df.iloc[:,3:4].values.tolist()
        val4 = df.iloc[:,4:5].values.tolist()
        flat3 = [item for sublist in val3 for item in sublist]
        flat4 = [str(item) for sublist in val4 for item in sublist]
        texts = [] 
        # 'Append' add x, but extend add x's elements
        texts.extend(flat3[:]) # Column Question1
        texts.extend(flat4[:]) # Column Question2
        sequences = tokenizer.texts_to_sequences(texts)
        data_train = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
        yield (data_train, data_train)

# %% [markdown]
# ### Word embeddings
# We will use pretrained Glove word embeddings as embeddings for our network. We create a matrix with one embedding for every word in our vocabulary and then we will pass this matrix as weights to the keras embedding layer of our model

# %%
GLOVE_EMBEDDING = BASE_DIR + 'GloVe/glove.6B.300d.txt'
EMBEDDING_DIM = 300

embeddings_index = {}
f = open(GLOVE_EMBEDDING, encoding='utf8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))

glove_embedding_matrix = np.zeros((NB_WORDS, EMBEDDING_DIM))
for word, i in word_index.items():
    if i < NB_WORDS:
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            # words not found in embedding index will be the word embedding of 'unk'.
            glove_embedding_matrix[i] = embedding_vector
        else:
            glove_embedding_matrix[i] = embeddings_index.get('unk')
print('Null word embeddings: %d' % np.sum(np.sum(glove_embedding_matrix, axis=1) == 0))
# Out:
# Found 400000 word vectors.
# Null word embeddings: 1

# %% [markdown]
# ### VAE model
# Our model is based on a seq2seq architecture with a bidirectional LSTM encoder and an LSTM decoder and ELU activations.
# We feed the latent representation at every timestep as input to the decoder through "RepeatVector(max_len)".
# To avoid the one-hot representation of labels we use the "tf.contrib.seq2seq.sequence_loss" that requires as labels only the word indexes (the same that go in input to the embedding matrix) and calculates internally the final softmax (so the model ends with a dense layer with linear activation). Optionally the "sequence_loss" allows to use the sampled softmax which helps when dealing with large vocabularies (for example with a 50k words vocabulary) but in this I didn't use it.
# Moreover, due to the pandas iterator that reads the csv both the train size and validation size must be divisible by the batch_size.

# %% [markdown]
# Exponential Linear Unit or its widely known name ELU is a function that tend to converge cost to zero faster and produce more accurate results. Different to other activation functions, ELU has a extra alpha constant which should be positive number.
#
# ELU is very similiar to RELU except negative inputs. They are both in identity function form for non-negative inputs. On the other hand, ELU becomes smooth slowly until its output equal to -α whereas RELU sharply smoothes.
#
# https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html#elu

# %%
batch_size = 100
max_len = MAX_SEQUENCE_LENGTH
emb_dim = EMBEDDING_DIM
latent_dim = 64
intermediate_dim = 192
epsilon_std = 1.0
act = ELU()
repeated_context = RepeatVector(max_len)

x = Input(batch_shape=(None, max_len))
x_embed = Embedding(NB_WORDS, emb_dim, weights=[glove_embedding_matrix],
                            input_length=max_len, trainable=False)(x)
h = Bidirectional(LSTM(intermediate_dim, return_sequences=False, recurrent_dropout=0.2), merge_mode='concat')(x_embed)
h = Dropout(0.2)(h)
h = Dense(intermediate_dim, activation='linear')(h)
h = act(h)
h = Dropout(0.2)(h)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)

def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(batch_size, latent_dim), mean=0.,
                              stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2) * epsilon

# note that "output_shape" isn't necessary with the TensorFlow backend
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# we instantiate these layers separately so as to reuse them later
repeated_context = RepeatVector(max_len)
decoder_h = LSTM(intermediate_dim, return_sequences=True, recurrent_dropout=0.2)
decoder_mean = TimeDistributed(Dense(NB_WORDS, activation='linear'))#softmax is applied in the seq2seqloss by tf

h_decoded = decoder_h(repeated_context(z))
x_decoded_mean = decoder_mean(h_decoded)


# placeholder loss
def zero_loss(y_true, y_pred):
    return K.zeros_like(y_pred)

# Custom VAE loss layer
class CustomVariationalLayer(Layer):
    def __init__(self, **kwargs):
        self.is_placeholder = True
        super(CustomVariationalLayer, self).__init__(**kwargs)
        self.target_weights = tf.constant(np.ones((batch_size, max_len)), tf.float32)

    def vae_loss(self, x, x_decoded_mean):
        labels = tf.cast(x, tf.int32)
        xent_loss = K.sum(tf.contrib.seq2seq.sequence_loss(x_decoded_mean, labels, 
                                                     weights=self.target_weights,
                                                     average_across_timesteps=False,
                                                     average_across_batch=False), axis=-1)
        kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
        return K.mean(xent_loss + kl_loss)

    def call(self, inputs):
        x = inputs[0]
        x_decoded_mean = inputs[1]
        print(x.shape, x_decoded_mean.shape)
        loss = self.vae_loss(x, x_decoded_mean)
        self.add_loss(loss, inputs=inputs)
        # we don't use this output, but it has to have the correct shape:
        return K.ones_like(x)

loss_layer = CustomVariationalLayer()([x, x_decoded_mean])
vae = Model(x, [loss_layer])
opt = Adam(lr=0.01) 
vae.compile(optimizer='adam', loss=[zero_loss])
vae.summary()
# Out:
# WARNING:tensorflow:From /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/keras/backend.py:4010: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# (?, 15) (100, 15, 12001)
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 15)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 15, 300)      3600300     input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 384)          757248      embedding[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 384)          0           bidirectional[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 192)          73920       dropout[0][0]
# __________________________________________________________________________________________________
# elu (ELU)                       (None, 192)          0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 192)          0           elu[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           12352       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           12352       dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (100, 64)            0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (100, 15, 64)        0           lambda[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (100, 15, 192)       197376      repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (100, 15, 12001)     2316193     lstm_1[0][0]
# __________________________________________________________________________________________________
# custom_variational_layer (Custo (None, 15)           0           input_1[0][0]
#                                                                  time_distributed[0][0]
# ==================================================================================================
# Total params: 6,969,741
# Trainable params: 3,369,441
# Non-trainable params: 3,600,300
# __________________________________________________________________________________________________

# %% [markdown]
# ### Model training
# We train our model for 100 epochs through keras ".fit_generator". The number of steps per epoch is equal to the number of sentences that we have in the train set (800000) divided by the batch size; the additional /2 is due to the fact that our csv has two sentnces per line so in the end we have to read with our generator only 400000 lines per epoch.
# For validation data we pass the same array twice since input and labels of this model are the same.
# If we didn't use the "tf.contrib.seq2seq.sequence_loss" (or another similar function) we would have had to pass as labels the sequence of word one-hot encodings with dimension (batch_size, seq_len, vocab_size) consuming a lot of memory.

# %%
import datetime
from tensorflow.python.keras.callbacks import TensorBoard

# %%
log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
callback = TensorBoard(log_dir)
callback.set_model([vae])

# %%
def write_log(callback, names, logs, batch_no):

    summary = tf.Summary()
    summary_value = summary.value.add()
    summary_value.simple_value = logs[0].history['loss'][0]
    summary_value.tag = names[0]
    callback.writer.add_summary(summary, batch_no)

    summary = tf.Summary()
    summary_value = summary.value.add()
    summary_value.simple_value = logs[0].history['val_loss'][0]
    summary_value.tag = names[1]
    callback.writer.add_summary(summary, batch_no)
    callback.writer.flush()

# %%
def create_model_checkpoint(dir, model_name):
    filepath = dir + '/' + model_name + ".h5" #-{epoch:02d}-{decoded_mean:.2f}
    directory = os.path.dirname(filepath)
    try:
        os.stat(directory)
    except:
        os.mkdir(directory)
    checkpointer = ModelCheckpoint(filepath=filepath, verbose=1, save_best_only=False)
    return checkpointer

checkpointer = create_model_checkpoint('models', 'vae_seq2seq')
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

nb_epoch=100
n_steps = int((800000/2)/batch_size)

for counter in range(nb_epoch):
    print('-------epoch: ',counter,'--------')
    history = vae.fit_generator(sent_generator(TRAIN_DATA_FILE, batch_size/2),
                          steps_per_epoch=n_steps, epochs=1, callbacks=[checkpointer],
                          validation_data=(data_1_val, data_1_val))
    write_log(callback, ['loss', 'val_loss'], [history], counter)
    
vae.save('models/300_e1_d1_ls64_itm192.h5')
# Out:
# -------epoch:  0 --------
# WARNING:tensorflow:From /home/ines/anaconda3/envs/tensorflow_gpu_1_13/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 6000/6000 [==============================] - 1s 209us/sample - loss: 64.0725
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 173s 43ms/step - loss: 69.3396 - val_loss: 64.0725
# -------epoch:  1 --------
# 6000/6000 [==============================] - 1s 172us/sample - loss: 61.7228
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 163s 41ms/step - loss: 62.9433 - val_loss: 61.7228
# -------epoch:  2 --------
# 6000/6000 [==============================] - 1s 172us/sample - loss: 60.9311
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 163s 41ms/step - loss: 61.6177 - val_loss: 60.9311
# -------epoch:  3 --------
# 6000/6000 [==============================] - 1s 173us/sample - loss: 60.7435
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 164s 41ms/step - loss: 60.9834 - val_loss: 60.7435
# -------epoch:  4 --------
# 6000/6000 [==============================] - 1s 172us/sample - loss: 59.9889
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 164s 41ms/step - loss: 60.4654 - val_loss: 59.9889
# -------epoch:  5 --------
# 6000/6000 [==============================] - 1s 173us/sample - loss: 58.7891
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 164s 41ms/step - loss: 59.5458 - val_loss: 58.7891
# -------epoch:  6 --------
# 6000/6000 [==============================] - 1s 173us/sample - loss: 58.2270
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 164s 41ms/step - loss: 58.4687 - val_loss: 58.2270
# -------epoch:  7 --------
# 6000/6000 [==============================] - 1s 174us/sample - loss: 57.9544
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 164s 41ms/step - loss: 57.9802 - val_loss: 57.9544
# -------epoch:  8 --------
# 6000/6000 [==============================] - 1s 163us/sample - loss: 57.6209
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 165s 41ms/step - loss: 57.6421 - val_loss: 57.6209
# -------epoch:  9 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 57.4846
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 160s 40ms/step - loss: 57.3968 - val_loss: 57.4846
# -------epoch:  10 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 57.3462
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 57.1738 - val_loss: 57.3462
# -------epoch:  11 --------
# 6000/6000 [==============================] - 1s 163us/sample - loss: 57.2546
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 57.0152 - val_loss: 57.2546
# -------epoch:  12 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 57.1484
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 56.8578 - val_loss: 57.1484
# -------epoch:  13 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 57.4804
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 56.7303 - val_loss: 57.4804
# -------epoch:  14 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 57.1523
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 56.6221 - val_loss: 57.1523
# -------epoch:  15 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 56.9890
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 56.5139 - val_loss: 56.9890
# -------epoch:  16 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 57.0541
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 56.4247 - val_loss: 57.0541
# -------epoch:  17 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 57.0107
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 56.3199 - val_loss: 57.0107
# -------epoch:  18 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 56.8840
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 56.2453 - val_loss: 56.8840
# -------epoch:  19 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 56.9347
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 56.1627 - val_loss: 56.9347
# -------epoch:  20 --------
# 6000/6000 [==============================] - 1s 163us/sample - loss: 56.8298
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 56.0851 - val_loss: 56.8298
# -------epoch:  21 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 56.8280
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 56.0293 - val_loss: 56.8280
# -------epoch:  22 --------
# 6000/6000 [==============================] - 1s 168us/sample - loss: 56.8623
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 55.9609 - val_loss: 56.8623
# -------epoch:  23 --------
# 6000/6000 [==============================] - 1s 163us/sample - loss: 56.7506
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 55.8947 - val_loss: 56.7506
# -------epoch:  24 --------
# 6000/6000 [==============================] - 1s 180us/sample - loss: 56.7959
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 169s 42ms/step - loss: 55.7986 - val_loss: 56.7959
# -------epoch:  25 --------
# 6000/6000 [==============================] - 1s 171us/sample - loss: 56.6351
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 163s 41ms/step - loss: 55.7192 - val_loss: 56.6351
# -------epoch:  26 --------
# 6000/6000 [==============================] - 1s 171us/sample - loss: 56.4459
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 163s 41ms/step - loss: 55.6428 - val_loss: 56.4459
# -------epoch:  27 --------
# 6000/6000 [==============================] - 1s 172us/sample - loss: 56.3819
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 162s 41ms/step - loss: 55.5170 - val_loss: 56.3819
# -------epoch:  28 --------
# 6000/6000 [==============================] - 1s 175us/sample - loss: 56.1868
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 162s 41ms/step - loss: 55.3555 - val_loss: 56.1868
# -------epoch:  29 --------
# 6000/6000 [==============================] - 1s 169us/sample - loss: 56.3348
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 162s 41ms/step - loss: 55.1901 - val_loss: 56.3348
# -------epoch:  30 --------
# 6000/6000 [==============================] - 1s 188us/sample - loss: 55.9348
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 163s 41ms/step - loss: 55.0799 - val_loss: 55.9348
# -------epoch:  31 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.9677
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 165s 41ms/step - loss: 54.9587 - val_loss: 55.9677
# -------epoch:  32 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.8876
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.8740 - val_loss: 55.8876
# -------epoch:  33 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.7746
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.8092 - val_loss: 55.7746
# -------epoch:  34 --------
# 6000/6000 [==============================] - 1s 167us/sample - loss: 55.9622
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.7227 - val_loss: 55.9622
# -------epoch:  35 --------
# 6000/6000 [==============================] - 1s 166us/sample - loss: 55.8156
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 160s 40ms/step - loss: 54.6597 - val_loss: 55.8156
# -------epoch:  36 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.6484
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.5785 - val_loss: 55.6484
# -------epoch:  37 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.6135
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.5317 - val_loss: 55.6135
# -------epoch:  38 --------
# 6000/6000 [==============================] - 1s 163us/sample - loss: 55.6031
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.4771 - val_loss: 55.6031
# -------epoch:  39 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.4515
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.4232 - val_loss: 55.4515
# -------epoch:  40 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.5299
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 168s 42ms/step - loss: 54.3994 - val_loss: 55.5299
# -------epoch:  41 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.5543
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.3237 - val_loss: 55.5543
# -------epoch:  42 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.6245
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.2743 - val_loss: 55.6245
# -------epoch:  43 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.7790
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.2525 - val_loss: 55.7790
# -------epoch:  44 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.3893
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.2301 - val_loss: 55.3893
# -------epoch:  45 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.4169
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.1755 - val_loss: 55.4169
# -------epoch:  46 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.3191
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 160s 40ms/step - loss: 54.1354 - val_loss: 55.3191
# -------epoch:  47 --------
# 6000/6000 [==============================] - 1s 166us/sample - loss: 55.4049
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.0902 - val_loss: 55.4049
# -------epoch:  48 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.3956
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.0823 - val_loss: 55.3956
# -------epoch:  49 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.4061
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.0275 - val_loss: 55.4061
# -------epoch:  50 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.2701
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 54.0162 - val_loss: 55.2701
# -------epoch:  51 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1942
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.9876 - val_loss: 55.1942
# -------epoch:  52 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1883
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.9660 - val_loss: 55.1883
# -------epoch:  53 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.2376
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.9351 - val_loss: 55.2376
# -------epoch:  54 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.2999
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.9207 - val_loss: 55.2999
# -------epoch:  55 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1919
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.8809 - val_loss: 55.1919
# -------epoch:  56 --------
# 6000/6000 [==============================] - 1s 167us/sample - loss: 55.2854
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.8633 - val_loss: 55.2854
# -------epoch:  57 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.4154
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.8712 - val_loss: 55.4154
# -------epoch:  58 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.1531
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.8421 - val_loss: 55.1531
# -------epoch:  59 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1991
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 163s 41ms/step - loss: 53.8188 - val_loss: 55.1991
# -------epoch:  60 --------
# 6000/6000 [==============================] - 1s 168us/sample - loss: 55.2815
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.7710 - val_loss: 55.2815
# -------epoch:  61 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1108
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.7785 - val_loss: 55.1108
# -------epoch:  62 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.1946
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.7337 - val_loss: 55.1946
# -------epoch:  63 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0985
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.7430 - val_loss: 55.0985
# -------epoch:  64 --------
# 6000/6000 [==============================] - 1s 163us/sample - loss: 55.2731
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.6961 - val_loss: 55.2731
# -------epoch:  65 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0828
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.7084 - val_loss: 55.0828
# -------epoch:  66 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.2183
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.6807 - val_loss: 55.2183
# -------epoch:  67 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0644
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.6819 - val_loss: 55.0644
# -------epoch:  68 --------
# 6000/6000 [==============================] - 1s 163us/sample - loss: 55.1228
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.6373 - val_loss: 55.1228
# -------epoch:  69 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0977
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.6356 - val_loss: 55.0977
# -------epoch:  70 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.1291
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.6321 - val_loss: 55.1291
# -------epoch:  71 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1669
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.6015 - val_loss: 55.1669
# -------epoch:  72 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0776
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.6289 - val_loss: 55.0776
# -------epoch:  73 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0459
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.5998 - val_loss: 55.0459
# -------epoch:  74 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1309
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.5623 - val_loss: 55.1309
# -------epoch:  75 --------
# 6000/6000 [==============================] - 1s 170us/sample - loss: 55.0799
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.5498 - val_loss: 55.0799
# -------epoch:  76 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0078
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.5437 - val_loss: 55.0078
# -------epoch:  77 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0937
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.5271 - val_loss: 55.0937
# -------epoch:  78 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0719
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.5196 - val_loss: 55.0719
# -------epoch:  79 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.2354
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4969 - val_loss: 55.2354
# -------epoch:  80 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0630
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.5052 - val_loss: 55.0630
# -------epoch:  81 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1168
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4966 - val_loss: 55.1168
# -------epoch:  82 --------
# 6000/6000 [==============================] - 1s 163us/sample - loss: 55.0500
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4984 - val_loss: 55.0500
# -------epoch:  83 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1132
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4819 - val_loss: 55.1132
# -------epoch:  84 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.3611
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4548 - val_loss: 55.3611
# -------epoch:  85 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 54.9970
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4436 - val_loss: 54.9970
# -------epoch:  86 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0225
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4282 - val_loss: 55.0225
# -------epoch:  87 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1221
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4269 - val_loss: 55.1221
# -------epoch:  88 --------
# 6000/6000 [==============================] - 1s 171us/sample - loss: 55.0299
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4306 - val_loss: 55.0299
# -------epoch:  89 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1178
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4161 - val_loss: 55.1178
# -------epoch:  90 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.3281
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4138 - val_loss: 55.3281
# -------epoch:  91 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.1869
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.4599 - val_loss: 55.1869
# -------epoch:  92 --------
# 6000/6000 [==============================] - 1s 163us/sample - loss: 55.1330
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.3856 - val_loss: 55.1330
# -------epoch:  93 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0868
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.3958 - val_loss: 55.0868
# -------epoch:  94 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.1811
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.3564 - val_loss: 55.1811
# -------epoch:  95 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.1160
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 160s 40ms/step - loss: 53.3780 - val_loss: 55.1160
# -------epoch:  96 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.0429
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.3706 - val_loss: 55.0429
# -------epoch:  97 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.1057
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 161s 40ms/step - loss: 53.3487 - val_loss: 55.1057
# -------epoch:  98 --------
# 6000/6000 [==============================] - 1s 164us/sample - loss: 55.0141
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.3817 - val_loss: 55.0141
# -------epoch:  99 --------
# 6000/6000 [==============================] - 1s 165us/sample - loss: 55.0832
#
# Epoch 00001: saving model to models/vae_seq2seq.h5
# 4000/4000 [==============================] - 159s 40ms/step - loss: 53.3556 - val_loss: 55.0832

# %% [markdown]
# ### Model Load

# %%
vae.load_weights('../models/300_e1_d1_ls64_itm192.h5')

# %% [markdown]
# ### Project and sample sentences from the latent space
# Now we build an encoder model that takes a sentence and projects it on the latent space
# and a decoder model that goes from the latent space back to the text representation

# %%
# build a model to project sentences on the latent space
encoder = Model(x, z_mean)

# build a generator that can sample sentences from the learned distribution
decoder_input = Input(shape=(latent_dim,))
_h_decoded = decoder_h(repeated_context(decoder_input))
_x_decoded_mean = decoder_mean(_h_decoded)
_x_decoded_mean = Activation('softmax')(_x_decoded_mean)
generator = Model(decoder_input, _x_decoded_mean)

# %% [markdown]
# ### Test on validation sentences

# %%
index2word = {v: k for k, v in word_index.items()}
sent_encoded = encoder.predict(data_1_val, batch_size = 16)
x_test_reconstructed = generator.predict(sent_encoded)
max_value = np.apply_along_axis(np.argmax, 1, x_test_reconstructed[0])

# %%
sent_idx = 672
# Apply a function to 1-D slices along the given axis.
reconstructed_indexes = np.apply_along_axis(np.argmax, 1, x_test_reconstructed[sent_idx])
print(reconstructed_indexes)

original_sent = list(np.vectorize(index2word.get)(data_1_val[sent_idx]))
o_list = [o for o in original_sent if o]
print(' '.join(o_list))

word_list = list(np.vectorize(index2word.get)(reconstructed_indexes))
w_list = [w for w in word_list if w]
print(' '.join(w_list))
# Out:
# [ 0  4 13  5 30  6  8 10  8  8  8  8  8  8 35]
# where can i find the full list of skills for the linkedin skills feature
# how can i get a in of in in in in in in india

# %%
import random

sent_idx1 = random.randint(1, 5000)
sent_idx2 = random.randint(1, 5000)
# Apply a function to 1-D slices along the given axis.

reconstructed_indexes = np.apply_along_axis(np.argmax, 1, x_test_reconstructed[sent_idx1])
print(sent_idx1)

word_list_1 = list(np.vectorize(index2word.get)(reconstructed_indexes))
w_list_1 = [w for w in word_list_1 if w]
print(' '.join(w_list))

original_sent_1 = list(np.vectorize(index2word.get)(data_1_val[sent_idx1]))
o_list_1 = [w for w in original_sent_1 if w]
print(' '.join(o_list_1))

reconstructed_indexes = np.apply_along_axis(np.argmax, 1, x_test_reconstructed[sent_idx2])
print(sent_idx2)

word_list_2 = list(np.vectorize(index2word.get)(reconstructed_indexes))
w_list_2 = [w for w in word_list_2 if w]
print(' '.join(w_list_2))

original_sent_2 = list(np.vectorize(index2word.get)(data_1_val[sent_idx2]))
o_list_2 = [w for w in original_sent_2 if w]
print(' '.join(o_list_2))
# Out:
# 1682
# how can i get a in of in in in in in in india
# various ways of using water that is from guard
# 4877
# is it like to to a a life
# can my cat catch a cold from me

# %% [markdown]
# ### Sentence processing and interpolation

# %%
# function to parse a sentence
def sent_parse(sentence, mat_shape):
    sequence = tokenizer.texts_to_sequences(sentence)
    padded_sent = pad_sequences(sequence, maxlen=MAX_SEQUENCE_LENGTH)
    return padded_sent#[padded_sent, sent_one_hot]

# input: encoded sentence vector
# output: encoded sentence vector in dataset with highest cosine similarity
def find_similar_encoding(sent_vect):
    all_cosine = []
    for sent in sent_encoded:
        result = 1 - spatial.distance.cosine(sent_vect, sent)
        all_cosine.append(result)
    data_array = np.array(all_cosine)
    maximum = data_array.argsort()[-3:][::-1][1]
    new_vec = sent_encoded[maximum]
    return new_vec

# input: two points, integer n
# output: n equidistant points on the line between the input points (inclusive)
def shortest_homology(point_one, point_two, num):
    dist_vec = point_two - point_one
    sample = np.linspace(0, 1, num, endpoint = True)
    hom_sample = []
    for s in sample:
        hom_sample.append(point_one + s * dist_vec)
    return hom_sample

# input: original dimension sentence vector
# output: sentence text
def print_latent_sentence(sent_vect):
    sent_vect = np.reshape(sent_vect,[1,latent_dim])
    sent_reconstructed = generator.predict(sent_vect)
    sent_reconstructed = np.reshape(sent_reconstructed,[max_len,NB_WORDS])
    reconstructed_indexes = np.apply_along_axis(np.argmax, 1, sent_reconstructed)
    np.apply_along_axis(np.max, 1, x_test_reconstructed[sent_idx])
    np.max(np.apply_along_axis(np.max, 1, x_test_reconstructed[sent_idx]))
    word_list = list(np.vectorize(index2word.get)(reconstructed_indexes))
    w_list = [w for w in word_list if w]
    print(' '.join(w_list))
    #print(word_list)
        
def new_sents_interp(sent1, sent2, n):
    tok_sent1 = sent_parse(sent1, [15])
    tok_sent2 = sent_parse(sent2, [15])
    enc_sent1 = encoder.predict(tok_sent1, batch_size = 16)
    enc_sent2 = encoder.predict(tok_sent2, batch_size = 16)
    test_hom = shortest_homology(enc_sent1, enc_sent2, n)
    for point in test_hom:
        print_latent_sentence(point)

# %% [markdown]
# ### Example
# Now we can try to parse two sentences and interpolate between them generating new sentences

# %%
sentence1 = [texts[sent_idx1]]
mysent = sent_parse(sentence1, [15])
mysent_encoded = encoder.predict(mysent, batch_size = 16)
print_latent_sentence(mysent_encoded)
print_latent_sentence(find_similar_encoding(mysent_encoded))

sentence2 = [texts[sent_idx2]]
mysent2 = sent_parse(sentence2, [15])
mysent_encoded2 = encoder.predict(mysent2, batch_size = 16)
print_latent_sentence(mysent_encoded2)
print_latent_sentence(find_similar_encoding(mysent_encoded2))
print('-----------------')

new_sents_interp(sentence1, sentence2, 6)
